# %% [markdown]
# ## Python数据分析第05天
#
# ### 1.1 Pandas的应用
#
# #### 1.1.1.数据重塑

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# %pip install -U pymysql cryptography

# %%
# %pip install sqlalchemy==1.4.0

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:123456@localhost:3306/hrs')
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/hrs)

# %%
dept_df = pd.read_sql('select dno as deptno, dname, dloc from tb_dept', engine)
dept_df
# Out:
#    deptno dname dloc
# 0      10   会计部   北京
# 1      20   研发部   成都
# 2      30   销售部   重庆
# 3      40   运维部   深圳
# 4      80  研发8部   天津
# 5      90  研发5部   北京

# %%
emp_df = pd.read_sql('select eno, ename, job, mgr, sal, comm, dno from tb_emp', engine)
emp_df
# Out:
#      eno ename   job     mgr    sal    comm  dno
# 0   1359   胡一刀   销售员  3344.0   2300   200.0   30
# 1   2056    乔峰   分析师  7800.0   6000  1500.0   20
# 2   3088   李莫愁   设计师  2056.0   4500   800.0   20
# 3   3211   张无忌   程序员  2056.0   4200     NaN   20
# 4   3233   丘处机   程序员  2056.0   4400     NaN   20
# 5   3244   欧阳锋   程序员  3088.0   4200     NaN   20
# 6   3251   张翠山   程序员  2056.0   5000     NaN   20
# 7   3344    黄蓉  销售主管  7800.0   3500   800.0   30
# 8   3577    杨过    会计  5566.0   2400     NaN   10
# 9   3588   朱九真    会计  5566.0   2700     NaN   10
# 10  4466   苗人凤   销售员  3344.0   3000     NaN   30
# 11  5234    郭靖    出纳  5566.0   2200     NaN   10
# 12  5566   宋远桥   会计师  7800.0   4200  1000.0   10
# 13  7800   张三丰    总裁     NaN  10000  1200.0   20

# %%
# dept_df.rename(columns={'dno': 'deptno'}) # 修改列名

# %%
temp_df = pd.merge(emp_df, dept_df, how='inner', left_on='dno', right_on='deptno')
temp_df
# Out:
#      eno ename   job     mgr    sal    comm  dno  deptno dname dloc
# 0   1359   胡一刀   销售员  3344.0   2300   200.0   30      30   销售部   重庆
# 1   3344    黄蓉  销售主管  7800.0   3500   800.0   30      30   销售部   重庆
# 2   4466   苗人凤   销售员  3344.0   3000     NaN   30      30   销售部   重庆
# 3   2056    乔峰   分析师  7800.0   6000  1500.0   20      20   研发部   成都
# 4   3088   李莫愁   设计师  2056.0   4500   800.0   20      20   研发部   成都
# 5   3211   张无忌   程序员  2056.0   4200     NaN   20      20   研发部   成都
# 6   3233   丘处机   程序员  2056.0   4400     NaN   20      20   研发部   成都
# 7   3244   欧阳锋   程序员  3088.0   4200     NaN   20      20   研发部   成都
# 8   3251   张翠山   程序员  2056.0   5000     NaN   20      20   研发部   成都
# 9   7800   张三丰    总裁     NaN  10000  1200.0   20      20   研发部   成都
# 10  3577    杨过    会计  5566.0   2400     NaN   10      10   会计部   北京
# 11  3588   朱九真    会计  5566.0   2700     NaN   10      10   会计部   北京
# 12  5234    郭靖    出纳  5566.0   2200     NaN   10      10   会计部   北京
# ...

# %%
temp_df.drop(columns=['deptno', 'job'])
# Out:
#      eno ename     mgr    sal    comm  dno dname dloc
# 0   1359   胡一刀  3344.0   2300   200.0   30   销售部   重庆
# 1   3344    黄蓉  7800.0   3500   800.0   30   销售部   重庆
# 2   4466   苗人凤  3344.0   3000     NaN   30   销售部   重庆
# 3   2056    乔峰  7800.0   6000  1500.0   20   研发部   成都
# 4   3088   李莫愁  2056.0   4500   800.0   20   研发部   成都
# 5   3211   张无忌  2056.0   4200     NaN   20   研发部   成都
# 6   3233   丘处机  2056.0   4400     NaN   20   研发部   成都
# 7   3244   欧阳锋  3088.0   4200     NaN   20   研发部   成都
# 8   3251   张翠山  2056.0   5000     NaN   20   研发部   成都
# 9   7800   张三丰     NaN  10000  1200.0   20   研发部   成都
# 10  3577    杨过  5566.0   2400     NaN   10   会计部   北京
# 11  3588   朱九真  5566.0   2700     NaN   10   会计部   北京
# 12  5234    郭靖  5566.0   2200     NaN   10   会计部   北京
# 13  5566   宋远桥  7800.0   4200  1000.0   10   会计部   北京

# %%
dept_df.set_index('deptno')
# Out:
#        dname dloc
# deptno
# 10       会计部   北京
# 20       研发部   成都
# 30       销售部   重庆
# 40       运维部   深圳
# 80      研发8部   天津
# 90      研发5部   北京

# %%
pd.merge(emp_df, dept_df, how='inner', left_on='dno', right_index=True)
# Out:
# Empty DataFrame
# Columns: [eno, ename, job, mgr, sal, comm, dno, deptno, dname, dloc]
# Index: []

# %% [markdown]
# 拼接表

# %%
import os 

filenames = os.listdir('data')  # 查看目录下的文件
all_dfs = [pd.read_csv(f'data\{filename}') for filename in filenames]  # 读取所有文件

jobs_df = pd.concat(all_df, ignore_index=True).drop(columns=['uri'])  # 合并所有文件,忽略索引,删除uri列
jobs_df

# %%
# jobs_df['job']  # 选择job列
# jobs_df.job  # 选择job列
# jobs_df[['job', 'company']] # 选择job和company列
# jobs_df[jobs_df.edu == '本科']  # 选择edu列等于本科的行

# %%
# jobs_df.loc[1] # 选择第1行
# jobs_df.loc[[1, 3, 5]]  # 选择第1,3,5行
# jobs_df.loc[1:5] # 选择第1行到第5行
# jobs_df.at[1, 'job'] # 选择第1行job列
# jobs_df.at[1, 'job'] = '数据分析师' # 修改第1行job列的值

# %%
# jobs_df['level'] = '优' # 添加level列,默认值为优
# jobs_df['level'] = ['优', '良', '中', '差'] * (9825 // 4) # 修改level列的值
# jobs_df.loc[9825] = {'company': '百度', 'job': '数据分析师'} # 添加一行

# %% [markdown]
# 数据清洗

# %%
emp_df.isna()
# Out:
#       eno  ename    job    mgr    sal   comm    dno
# 0   False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False
# 3   False  False  False  False  False   True  False
# 4   False  False  False  False  False   True  False
# 5   False  False  False  False  False   True  False
# 6   False  False  False  False  False   True  False
# 7   False  False  False  False  False  False  False
# 8   False  False  False  False  False   True  False
# 9   False  False  False  False  False   True  False
# 10  False  False  False  False  False   True  False
# 11  False  False  False  False  False   True  False
# 12  False  False  False  False  False  False  False
# 13  False  False  False   True  False  False  False

# %%
emp_df.dropna()
# Out:
#      eno ename   job     mgr   sal    comm  dno
# 0   1359   胡一刀   销售员  3344.0  2300   200.0   30
# 1   2056    乔峰   分析师  7800.0  6000  1500.0   20
# 2   3088   李莫愁   设计师  2056.0  4500   800.0   20
# 7   3344    黄蓉  销售主管  7800.0  3500   800.0   30
# 12  5566   宋远桥   会计师  7800.0  4200  1000.0   10

# %%
emp_df.dropna(axis=1)
# Out:
#      eno ename   job    sal  dno
# 0   1359   胡一刀   销售员   2300   30
# 1   2056    乔峰   分析师   6000   20
# 2   3088   李莫愁   设计师   4500   20
# 3   3211   张无忌   程序员   4200   20
# 4   3233   丘处机   程序员   4400   20
# 5   3244   欧阳锋   程序员   4200   20
# 6   3251   张翠山   程序员   5000   20
# 7   3344    黄蓉  销售主管   3500   30
# 8   3577    杨过    会计   2400   10
# 9   3588   朱九真    会计   2700   10
# 10  4466   苗人凤   销售员   3000   30
# 11  5234    郭靖    出纳   2200   10
# 12  5566   宋远桥   会计师   4200   10
# 13  7800   张三丰    总裁  10000   20

# %%
emp_df.fillna(0)
# Out:
#      eno ename   job     mgr    sal    comm  dno
# 0   1359   胡一刀   销售员  3344.0   2300   200.0   30
# 1   2056    乔峰   分析师  7800.0   6000  1500.0   20
# 2   3088   李莫愁   设计师  2056.0   4500   800.0   20
# 3   3211   张无忌   程序员  2056.0   4200     0.0   20
# 4   3233   丘处机   程序员  2056.0   4400     0.0   20
# 5   3244   欧阳锋   程序员  3088.0   4200     0.0   20
# 6   3251   张翠山   程序员  2056.0   5000     0.0   20
# 7   3344    黄蓉  销售主管  7800.0   3500   800.0   30
# 8   3577    杨过    会计  5566.0   2400     0.0   10
# 9   3588   朱九真    会计  5566.0   2700     0.0   10
# 10  4466   苗人凤   销售员  3344.0   3000     0.0   30
# 11  5234    郭靖    出纳  5566.0   2200     0.0   10
# 12  5566   宋远桥   会计师  7800.0   4200  1000.0   10
# 13  7800   张三丰    总裁     0.0  10000  1200.0   20

# %%
emp_df['comm'] = emp_df['comm'].fillna(0).astype(np.int64) # 填充comm列的空值为0,并转换为整型
emp_df
# Out:
#      eno ename   job     mgr    sal  comm  dno
# 0   1359   胡一刀   销售员  3344.0   2300   200   30
# 1   2056    乔峰   分析师  7800.0   6000  1500   20
# 2   3088   李莫愁   设计师  2056.0   4500   800   20
# 3   3211   张无忌   程序员  2056.0   4200     0   20
# 4   3233   丘处机   程序员  2056.0   4400     0   20
# 5   3244   欧阳锋   程序员  3088.0   4200     0   20
# 6   3251   张翠山   程序员  2056.0   5000     0   20
# 7   3344    黄蓉  销售主管  7800.0   3500   800   30
# 8   3577    杨过    会计  5566.0   2400     0   10
# 9   3588   朱九真    会计  5566.0   2700     0   10
# 10  4466   苗人凤   销售员  3344.0   3000     0   30
# 11  5234    郭靖    出纳  5566.0   2200     0   10
# 12  5566   宋远桥   会计师  7800.0   4200  1000   10
# 13  7800   张三丰    总裁     NaN  10000  1200   20

# %%
emp_df.duplicated('job') # 查看job列是否有重复值
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
emp_df.drop_duplicates('job', keep='first') # 删除重复的job列,保留第一行
# Out:
#      eno ename   job     mgr    sal  comm  dno
# 0   1359   胡一刀   销售员  3344.0   2300   200   30
# 1   2056    乔峰   分析师  7800.0   6000  1500   20
# 2   3088   李莫愁   设计师  2056.0   4500   800   20
# 3   3211   张无忌   程序员  2056.0   4200     0   20
# 7   3344    黄蓉  销售主管  7800.0   3500   800   30
# 8   3577    杨过    会计  5566.0   2400     0   10
# 11  5234    郭靖    出纳  5566.0   2200     0   10
# 12  5566   宋远桥   会计师  7800.0   4200  1000   10
# 13  7800   张三丰    总裁     NaN  10000  1200   20

# %%
sales_df = pd.read_csv(r'C:\Users\wdl\Data-analysis\data\某招聘网站招聘数据.csv')
sales_df
# Out:
#         no                       _id  adWord  appShow  approve  \
# 0        0  5de5e75734e608e63026c1bc       9        0        1
# 1        1  5de5e75734e608e63026c1bd       0        0        1
# 2        2  5de5e75734e608e63026c1be       0        0        1
# 3        3  5de5e75734e608e63026c1bf       0        0        0
# 4        4  5de5e75734e608e63026c1c0       0        0        0
# ...    ...                       ...     ...      ...      ...
# 3135  3135  5de5ea1134e608e63026cdfb       0        0        1
# 3136  3136  5de5ea1134e608e63026cdfc       0        0        1
# 3137  3137  5de5ea1134e608e63026cdfd       0        0        1
# 3138  3138  5de5ea1134e608e63026cdfe       0        0        1
# 3139  3139  5de5ea1134e608e63026cdff       0        0        1
#
#                businessZones city   companyFullName  companyId  \
# 0                     ['亦庄']   北京    达疆网络科技（上海）有限公司      32836
# 1                        NaN   北京      北京音娱时光科技有限公司     286568
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   no                     3140 non-null   int64
#  1   _id                    3140 non-null   object
#  2   adWord                 3140 non-null   int64
#  3   appShow                3140 non-null   int64
#  4   approve                3140 non-null   int64
#  5   businessZones          1544 non-null   object
#  6   city                   3140 non-null   object
#  7   companyFullName        3140 non-null   object
#  8   companyId              3140 non-null   int64
#  9   companyLabelList       3140 non-null   object
#  10  companyLogo            3139 non-null   object
#  11  companyShortName       3140 non-null   object
#  12  companySize            3140 non-null   object
#  13  createTime             3140 non-null   object
# ...

# %%
sales_df.drop(columns=['_id', 'no','adWord','appShow','approve']) # 删除无用列
# Out:
#                businessZones city   companyFullName  companyId  \
# 0                     ['亦庄']   北京    达疆网络科技（上海）有限公司      32836
# 1                        NaN   北京      北京音娱时光科技有限公司     286568
# 2                    ['西北旺']   北京     北京千喜鹤餐饮管理有限公司     278964
# 3                        NaN   北京     吉林省海生电子商务有限公司     399744
# 4     ['大望路', '建外大街', '南磨房']   北京    韦博网讯科技（北京）有限公司     580170
# ...                      ...  ...               ...        ...
# 3135         ['和平路', '荣业大街']   天津  清博津商（天津）教育科技有限公司     260578
# 3136                     NaN   天津  上海礼紫股权投资基金管理有限公司     264817
# 3137                  ['中北']   天津    北京达佳互联信息技术有限公司       1880
# 3138    ['南营门', '南市', '海光寺']   天津     北京河狸家信息技术有限公司      25854
# 3139    ['南营门', '南市', '海光寺']   天津     北京河狸家信息技术有限公司      25854
#
#                       companyLabelList  \
# 0     ['年底双薪', '绩效奖金', '岗位晋升', '定期体检']
# 1     ['年底双薪', '绩效奖金', '带薪年假', '免费健身']
# 2                                   []
# 3                                   []
# ...

# %%
city_df = sales_df.drop_duplicates('city') 
city_df
# Out:
#         no                       _id  adWord  appShow  approve  \
# 0        0  5de5e75734e608e63026c1bc       9        0        1
# 450    450  5de5e7b234e608e63026c37e       9        0        1
# 815    815  5de5e80a34e608e63026c4eb       0        0        0
# 1075  1075  5de5e84534e608e63026c5ef       0        0        1
# 1253  1253  5de5e86d34e608e63026c6a1       0        0        1
# 1371  1371  5de5e88c34e608e63026c717       0        0        1
# 1821  1821  5de5e8ea34e608e63026c8d9       0        0        0
# 2063  2063  5de5e91d34e608e63026c9cb       0        0        1
# 2513  2513  5de5e97f34e608e63026cb8d       0        0        1
# 2682  2682  5de5e9ab34e608e63026cc36       0        0        1
# 2815  2815  5de5e9ca34e608e63026ccbb       0        0        1
# 2967  2967  5de5e9f034e608e63026cd53       0        0        1
# 3065  3065  5de5ea0734e608e63026cdb5       0        0        1
#
#               businessZones city   companyFullName  companyId  \
# ...

# %%
city_df.city.value_counts()
# Out:
# 北京    1
# 上海    1
# 深圳    1
# 广州    1
# 杭州    1
# 成都    1
# 南京    1
# 武汉    1
# 西安    1
# 厦门    1
# 长沙    1
# 苏州    1
# 天津    1
# Name: city, dtype: int64

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   no                     3140 non-null   int64
#  1   _id                    3140 non-null   object
#  2   adWord                 3140 non-null   int64
#  3   appShow                3140 non-null   int64
#  4   approve                3140 non-null   int64
#  5   businessZones          1544 non-null   object
#  6   city                   3140 non-null   object
#  7   companyFullName        3140 non-null   object
#  8   companyId              3140 non-null   int64
#  9   companyLabelList       3140 non-null   object
#  10  companyLogo            3139 non-null   object
#  11  companyShortName       3140 non-null   object
#  12  companySize            3140 non-null   object
#  13  createTime             3140 non-null   object
# ...

# %%
sales_df['createTime'] = pd.to_datetime(sales_df.createTime)
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   no                     3140 non-null   int64
#  1   _id                    3140 non-null   object
#  2   adWord                 3140 non-null   int64
#  3   appShow                3140 non-null   int64
#  4   approve                3140 non-null   int64
#  5   businessZones          1544 non-null   object
#  6   city                   3140 non-null   object
#  7   companyFullName        3140 non-null   object
#  8   companyId              3140 non-null   int64
#  9   companyLabelList       3140 non-null   object
#  10  companyLogo            3139 non-null   object
#  11  companyShortName       3140 non-null   object
#  12  companySize            3140 non-null   object
#  13  createTime             3140 non-null   datetime64[ns]
# ...

# %%
sales_df['year'] = sales_df.createTime.dt.year
sales_df['month'] = sales_df.createTime.dt.month
sales_df['day'] = sales_df.createTime.dt.day
sales_df
# Out:
#         no                       _id  adWord  appShow  approve  \
# 0        0  5de5e75734e608e63026c1bc       9        0        1
# 1        1  5de5e75734e608e63026c1bd       0        0        1
# 2        2  5de5e75734e608e63026c1be       0        0        1
# 3        3  5de5e75734e608e63026c1bf       0        0        0
# 4        4  5de5e75734e608e63026c1c0       0        0        0
# ...    ...                       ...     ...      ...      ...
# 3135  3135  5de5ea1134e608e63026cdfb       0        0        1
# 3136  3136  5de5ea1134e608e63026cdfc       0        0        1
# 3137  3137  5de5ea1134e608e63026cdfd       0        0        1
# 3138  3138  5de5ea1134e608e63026cdfe       0        0        1
# 3139  3139  5de5ea1134e608e63026cdff       0        0        1
#
#                businessZones city   companyFullName  companyId  \
# 0                     ['亦庄']   北京    达疆网络科技（上海）有限公司      32836
# 1                        NaN   北京      北京音娱时光科技有限公司     286568
# ...

# %%
sales_df['imState'] = sales_df.imState.str.capitalize()
sales_df
# Out:
#         no                       _id  adWord  appShow  approve  \
# 0        0  5de5e75734e608e63026c1bc       9        0        1
# 1        1  5de5e75734e608e63026c1bd       0        0        1
# 2        2  5de5e75734e608e63026c1be       0        0        1
# 3        3  5de5e75734e608e63026c1bf       0        0        0
# 4        4  5de5e75734e608e63026c1c0       0        0        0
# ...    ...                       ...     ...      ...      ...
# 3135  3135  5de5ea1134e608e63026cdfb       0        0        1
# 3136  3136  5de5ea1134e608e63026cdfc       0        0        1
# 3137  3137  5de5ea1134e608e63026cdfd       0        0        1
# 3138  3138  5de5ea1134e608e63026cdfe       0        0        1
# 3139  3139  5de5ea1134e608e63026cdff       0        0        1
#
#                businessZones city   companyFullName  companyId  \
# 0                     ['亦庄']   北京    达疆网络科技（上海）有限公司      32836
# 1                        NaN   北京      北京音娱时光科技有限公司     286568
# ...
